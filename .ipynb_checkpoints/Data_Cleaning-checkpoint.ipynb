# %%
### Run this cell before continuing. 
library(tidyverse)
library(repr)
library(scales)
options(repr.matrix.max.rows = 6)
source("tests.R")
source("cleanup.R")
# Out:
# Warning message in file(filename, "r", encoding = encoding):
# “cannot open file 'tests.R': No such file or directory”
# Error in file(filename, "r", encoding = encoding): cannot open the connection
# Traceback:
#
# 1. source("tests.R")
# 2. file(filename, "r", encoding = encoding)

# %%
# Objects discuseed:
#1. created new_df to extract and wrangle data.
#2. Output Standards: New Column Added: Average Streams/Day, in_Spotify_playlists
#3. Use Data Visualization to Test Correlations, Discover Patterns according to each of % variables.
#4. Regresssion Problem: 
#5. Regresssion Problem:  
#6. Post-Stop Date: August 1st,  2023.
#7.  date_count_between()

# %%
spotify = read_csv('spotify-2023.csv')
head(spotify, n=10)
# Out:
# Rows: 953 Columns: 24
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (5): track_name, artist(s)_name, streams, key, mode
# dbl (17): artist_count, released_year, released_month, released_day, in_spot...
# num  (2): in_deezer_playlists, in_shazam_charts
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    track_name                          artist(s)_name        artist_count
# 1  Seven (feat. Latto) (Explicit Ver.) Latto, Jung Kook      2
# 2  LALA                                Myke Towers           1
# 3  vampire                             Olivia Rodrigo        1
# ⋮  ⋮                                   ⋮                     ⋮
# 8  Columbia                            Quevedo               1
# 9  fukumean                            Gunna                 1
# ...

# %%
new_df <- filter(spotify, released_year==2023)
new_df <- arrange(new, released_month)
new_df <- arrange(new, released_day)
# Out:
# Error in UseMethod("arrange"): no applicable method for 'arrange' applied to an object of class "function"
# Traceback:
#
# 1. arrange(new, released_month)

# %%
# new_df <- mutate(new_df, total_date_released = (as.Date(released_year + "-" + '0' + released_month + released_day)))
date1 <- as.Date(with(new_df, paste(released_year, released_month, released_day, sep = "-")))

# %%
new_df<- mutate(new_df, released_date=as.Date(with(new_df, paste(released_year, released_month, released_day, sep = "-"))))

# %%
Stop_Date <- as.Date('2023-08-01')

# %%
new_df<- mutate(new_df, date_difference= as.numeric(Stop_Date - released_date))

# %%
new_df
# Out:
#     track_name                          artist(s)_name
# 1   Seven (feat. Latto) (Explicit Ver.) Latto, Jung Kook
# 2   LALA                                Myke Towers
# 3   vampire                             Olivia Rodrigo
# ⋮   ⋮                                   ⋮
# 173 VIBE (feat. Jimin of BTS)           TAEYANG, Jimin
# 174 Mu��                                Steve Aoki, Tini, La Joaqui
# 175 Sugar Rush Ride                     TOMORROW X TOGETHER
#     artist_count released_year released_month released_day in_spotify_playlists
# 1   2            2023          7              14            553
# 2   1            2023          3              23           1474
# 3   1            2023          6              30           1397
# ⋮   ⋮            ⋮             ⋮              ⋮            ⋮
# 173 2            2023          1              13           415
# 174 3            2023          1              12           658
# 175 1            2023          1              27           359
# ...

# %%
new_df <- mutate(new_df, streams= as.numeric(streams))
new_df <- mutate(new_df, daily_streams= streams/date_difference)
new_df
# Out:
#     track_name                          artist(s)_name
# 1   Seven (feat. Latto) (Explicit Ver.) Latto, Jung Kook
# 2   LALA                                Myke Towers
# 3   vampire                             Olivia Rodrigo
# ⋮   ⋮                                   ⋮
# 173 VIBE (feat. Jimin of BTS)           TAEYANG, Jimin
# 174 Mu��                                Steve Aoki, Tini, La Joaqui
# 175 Sugar Rush Ride                     TOMORROW X TOGETHER
#     artist_count released_year released_month released_day in_spotify_playlists
# 1   2            2023          7              14            553
# 2   1            2023          3              23           1474
# 3   1            2023          6              30           1397
# ⋮   ⋮            ⋮             ⋮              ⋮            ⋮
# 173 2            2023          1              13           415
# 174 3            2023          1              12           658
# 175 1            2023          1              27           359
# ...

# %%
instrumentalness_plot <- ggplot(new_df, aes(x=`instrumentalness_%`, y=daily_streams)) + geom_scatter(color='red') + labs(x='valence', y='Daily Streams')
instrumentalness_plot
# Out:
# Error in geom_scatter(color = "red"): could not find function "geom_scatter"
# Traceback:

# %%
danceability_plot <- ggplot(new_df, aes(x=`danceability_%`, y=daily_streams)) + geom_point(color='red') + labs(x='valence', y='Daily Streams')+
                        scale_y_log10()
danceability_plot
# Out:
# plot without title

# %%
valence_plot <- ggplot(new_df, aes(x=`valence_%`, y=daily_streams)) + geom_point(color='red') + labs(x='valence', y='Daily Streams')+
                        scale_y_log10()
valence_plot
# Out:
# plot without title

# %%
energy_plot <- ggplot(new_df, aes(x=`energy_%`, y=daily_streams)) + geom_point(colour='purple') + labs(x='Energy', y='Daily Streams')+scale_y_log10()
energy_plot
# Out:
# plot without title

# %%
acousticness_plot <- ggplot(new_df, aes(x=`acousticness_%`, y=daily_streams)) + geom_point(color='purple') + labs(x='acousticness', y='Daily Streams')+
                        scale_y_log10()
acousticness_plot
# Out:
# plot without title
