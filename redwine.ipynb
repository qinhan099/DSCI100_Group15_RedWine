# %%
library(tidyverse)
library(repr)
library(scales)
source("tests.R")
source("cleanup.R")

# %%
wine <- read_csv('winequality-red.csv')
wine
# Out:
# Rows: 1599 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (12): fixed_acidity, volatile_acidity, citric_acid, residual_sugar, chlo...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      fixed_acidity volatile_acidity citric_acid residual_sugar chlorides
# 1     7.4          0.700            0.00        1.9            0.076
# 2     7.8          0.880            0.00        2.6            0.098
# 3     7.8          0.760            0.04        2.3            0.092
# 4    11.2          0.280            0.56        1.9            0.075
# 5     7.4          0.700            0.00        1.9            0.076
# 6     7.4          0.660            0.00        1.8            0.075
# 7     7.9          0.600            0.06        1.6            0.069
# ...

# %%
mean1<- group_by(wine, quality) |> 
    summarize(mean_fixed_acidity = mean(fixed_acidity))
mean1
mean_fixed_acidity_plot <- ggplot(mean1, aes(x=quality, y=mean_fixed_acidity)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of fixed acidity')

mean_fixed_acidity_plot
# Out:
#   quality mean_fixed_acidity
# 1 3       8.360000
# 2 4       7.779245
# 3 5       8.167254
# 4 6       8.347179
# 5 7       8.872362
# 6 8       8.566667
# plot without title

# %%
mean2<- group_by(wine, quality) |> 
    summarize(mean_volatile_acidity = mean(volatile_acidity))
mean2
mean_volatile_acidity_plot <- ggplot(mean2, aes(x=quality, y=mean_volatile_acidity)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of volatile acidity)')

mean_volatile_acidity_plot
# Out:
#   quality mean_volatile_acidity
# 1 3       0.8845000
# 2 4       0.6939623
# 3 5       0.5770411
# 4 6       0.4974843
# 5 7       0.4039196
# 6 8       0.4233333
# plot without title

# %%
mean3<- group_by(wine, quality) |> 
    summarize(mean_citric_acid = mean(citric_acid))
mean3
mean_citric_acid_plot <- ggplot(mean3, aes(x=quality, y=mean_citric_acid)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of citric acid)')

mean_citric_acid_plot
# Out:
#   quality mean_citric_acid
# 1 3       0.1710000
# 2 4       0.1741509
# 3 5       0.2436858
# 4 6       0.2738245
# 5 7       0.3751759
# 6 8       0.3911111
# plot without title

# %%
mean4<- group_by(wine, quality) |> 
    summarize(mean_residual_sugar = mean(residual_sugar))
mean4
mean_residual_sugar_plot <- ggplot(mean4, aes(x=quality, y=mean_residual_sugar)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of residual sugar)')

mean_residual_sugar_plot
# Out:
#   quality mean_residual_sugar
# 1 3       2.635000
# 2 4       2.694340
# 3 5       2.528855
# 4 6       2.477194
# 5 7       2.720603
# 6 8       2.577778
# plot without title

# %%
mean5<- group_by(wine, quality) |> 
    summarize(mean_chlorides = mean(chlorides))
mean5
mean_chlorides_plot <- ggplot(mean5, aes(x=quality, y=mean_chlorides)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of chlorides)')

mean_chlorides_plot
# Out:
#   quality mean_chlorides
# 1 3       0.12250000
# 2 4       0.09067925
# 3 5       0.09273568
# 4 6       0.08495611
# 5 7       0.07658794
# 6 8       0.06844444
# plot without title

# %%
mean6<- group_by(wine, quality) |> 
    summarize(mean_free_sulfur_dioxide = mean(free_sulfur_dioxide))
mean6
mean_free_sulfur_dioxide_plot <- ggplot(mean6, aes(x=quality, y=mean_free_sulfur_dioxide)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of free sulfur dioxide)')

mean_free_sulfur_dioxide_plot
# Out:
#   quality mean_free_sulfur_dioxide
# 1 3       11.00000
# 2 4       12.26415
# 3 5       16.98385
# 4 6       15.71160
# 5 7       14.04523
# 6 8       13.27778
# plot without title

# %%
mean7<- group_by(wine, quality) |> 
    summarize(mean_total_sulfur_dioxide = mean(total_sulfur_dioxide))
mean7
mean_total_sulfur_dioxide_plot <- ggplot(mean7, aes(x=quality, y=mean_total_sulfur_dioxide)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of total sulfur dioxide)')

mean_total_sulfur_dioxide_plot
# Out:
#   quality mean_total_sulfur_dioxide
# 1 3       24.90000
# 2 4       36.24528
# 3 5       56.51395
# 4 6       40.86991
# 5 7       35.02010
# 6 8       33.44444
# plot without title

# %%
mean8<- group_by(wine, quality) |> 
    summarize(mean_density = mean(density))
mean8 <- mutate(mean8, mean_density_scaled = mean_density - 0.99)
mean8
mean_density_plot <- ggplot(mean8, aes(x=quality, y=mean_density)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of density)') +
    geom_hline(yintercept = 0.996, linetype = "dashed", color = "red", linewidth = 0.5)
mean_density_plot

mean_density_scaled_plot <- ggplot(mean8, aes(x=quality, y=mean_density_scaled)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='scaled mean density)') 
mean_density_scaled_plot
# Out:
#   quality mean_density mean_density_scaled
# 1 3       0.9974640    0.007464000
# 2 4       0.9965425    0.006542453
# 3 5       0.9971036    0.007103627
# 4 6       0.9966151    0.006615063
# 5 7       0.9961043    0.006104271
# 6 8       0.9952122    0.005212222
# plot without title
# plot without title

# %%
mean9<- group_by(wine, quality) |> 
    summarize(mean_pH = mean(pH))
mean9
mean_pH_plot <- ggplot(mean9, aes(x=quality, y=mean_pH)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of pH)')+
    geom_hline(yintercept = 3.30, linetype = "dashed", colour = "red", linewidth = 0.5)

mean_pH_plot
# Out:
#   quality mean_pH
# 1 3       3.398000
# 2 4       3.381509
# 3 5       3.304949
# 4 6       3.318072
# 5 7       3.290754
# 6 8       3.267222
# plot without title

# %%
mean10<- group_by(wine, quality) |> 
    summarize(mean_sulphates = mean(sulphates))
mean10
mean_sulphates_plot <- ggplot(mean10, aes(x=quality, y=mean_sulphates)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of sulphates)')

mean_sulphates_plot
# Out:
#   quality mean_sulphates
# 1 3       0.5700000
# 2 4       0.5964151
# 3 5       0.6209692
# 4 6       0.6753292
# 5 7       0.7412563
# 6 8       0.7677778
# plot without title

# %%
mean11<- group_by(wine, quality) |> 
    summarize(mean_alcohol = mean(alcohol))
mean11
mean_alcohol_plot <- ggplot(mean11, aes(x=quality, y=mean_alcohol)) + 
    geom_bar(stat="identity") + 
    labs(x='quality', y='mean of alcohol)')

mean_alcohol_plot
# Out:
#   quality mean_alcohol
# 1 3        9.955000
# 2 4       10.265094
# 3 5        9.899706
# 4 6       10.629519
# 5 7       11.465913
# 6 8       12.094444
# plot without title

# %%
tokenization_plot <- ggplot(wine, aes(x=quality)) + 
    geom_histogram() 

tokenization_plot
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
